# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/raw/strains.csv')
df.head()
# Out:
#       Unnamed: 0      id  averageRating category  \
# 0              0  233839       4.564078   Hybrid
# 1              1   65591       4.639808   Hybrid
# 2              2  504256       4.557951   Hybrid
# 3              3  503179       4.618434   Indica
# 4              4  174127       4.600363   Hybrid
# ...          ...     ...            ...      ...
# 6148        6148  505850       0.000000      NaN
# 6149        6149  505849       0.000000      NaN
# 6150        6150  505848       4.500000      NaN
# 6151        6151  505844       5.000000      NaN
# 6152        6152   66643       4.384615   Indica
#
#                                          flowerImageSvg            name  \
# 0     https://public.leafly.com/strains/flowers/wedd...    Wedding Cake
# 1     https://public.leafly.com/strains/flowers/orig...             GG4
# 2     https://public.leafly.com/strains/flowers/runt...           Runtz
# 3     https://public.leafly.com/strains/flowers/ice-...  Ice Cream Cake
# ...

# %%
df2 = df.dropna(axis=1, how='all')
# Out:
#       Unnamed: 0      id  averageRating category  \
# 0              0  233839       4.564078   Hybrid
# 1              1   65591       4.639808   Hybrid
# 2              2  504256       4.557951   Hybrid
# 3              3  503179       4.618434   Indica
# 4              4  174127       4.600363   Hybrid
# ...          ...     ...            ...      ...
# 6148        6148  505850       0.000000      NaN
# 6149        6149  505849       0.000000      NaN
# 6150        6150  505848       4.500000      NaN
# 6151        6151  505844       5.000000      NaN
# 6152        6152   66643       4.384615   Indica
#
#                                          flowerImageSvg            name  \
# 0     https://public.leafly.com/strains/flowers/wedd...    Wedding Cake
# 1     https://public.leafly.com/strains/flowers/orig...             GG4
# 2     https://public.leafly.com/strains/flowers/runt...           Runtz
# 3     https://public.leafly.com/strains/flowers/ice-...  Ice Cream Cake
# ...

# %%
drop_list = [i for i in df2.columns if df2[i].nunique() < 2]
drop_list
# Out:
# ['cannabinoids_cbc_displayName',
#  'cannabinoids_cbd_displayName',
#  'cannabinoids_cbg_displayName',
#  'cannabinoids_thc_displayName',
#  'cannabinoids_thcv_displayName',
#  'effects_aroused_name',
#  'effects_creative_name',
#  'effects_energetic_name',
#  'effects_euphoric_name',
#  'effects_focused_name',
#  'effects_giggly_name',
#  'effects_happy_name',
#  'effects_hungry_name',
#  'effects_relaxed_name',
#  'effects_sleepy_name',
#  'effects_talkative_name',
#  'effects_tingly_name',
#  'effects_uplifted_name',
#  'terps_caryophyllene_name',
#  'terps_humulene_name',
#  'terps_limonene_name',
#  'terps_linalool_name',
#  'terps_myrcene_name',
#  'terps_ocimene_name',
#  'terps_pinene_name',
#  'terps_terpinolene_name']

# %%
df3 = df2.drop(columns=drop_list)
df4 = df3.drop(columns=['flowerImageSvg','nugImage','shortDescriptionPlain', 'distanceMi', 'subtitle'])
# Out:
# (6153, 51)

# %%
print(df.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
# Out:
# (6153, 133)
# (6153, 80)
# (6153, 54)
# (6153, 51)

# %%
# Out:
# /Users/jachiike/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
df4.isna().sum().sort_values(ascending=False)
# Out:
# distanceMi                        5744
# subtitle                          4987
# parent_2                          3844
# cannabinoids_thcv_percentile50    3529
# cannabinoids_cbc_percentile50     3466
# terps_humulene_score              3219
# cannabinoids_thc_percentile75     3219
# cannabinoids_thc_percentile25     3219
# terps_terpinolene_score           3219
# terps_pinene_score                3219
# strainTopTerp                     3219
# cannabinoids_cbd_percentile75     3219
# terps_limonene_score              3219
# terps_caryophyllene_score         3219
# terps_ocimene_score               3219
# terps_myrcene_score               3219
# cannabinoids_cbd_percentile25     3219
# terps_linalool_score              3219
# cannabinoids_cbg_percentile50     3216
# cannabinoids_cbd_percentile50     3213
# thc                               3135
# cannabinoids_thc_percentile50     3135
# parent_1                          2942
# slug_lineage                      2758
# ...

# %%
# drop columns with order in it

# %%
# drop distance

# %%
df4[df4.reviewCount > 1].shape
# Out:
# (4820, 51)

# %%
df4.to_csv('../../data/interim/strains.csv')

# %%
a = pd.read_csv('./Sample+Data.csv')

# %%
a.score.mean()
# Out:
# 8.596731802079763

# %%
a.received_at.str.replace(',','').astype('datetime64[ns]')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     654         try:
# --> 655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in _build_naive(self, res, default)
#    1240
# -> 1241         naive = default.replace(**repl)
#    1242
#
# ValueError: year 44163 is out of range
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ...
